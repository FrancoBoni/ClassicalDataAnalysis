# %%
# imports
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.graphics.regressionplots import abline_plot

# %%
# read data into a DataFrame
df = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
X = df["radio"]
y = df["sales"]

# %%
X = sm.add_constant(X) 
X.head()
# Out:
#    const  radio
# 1    1.0   37.8
# 2    1.0   39.3
# 3    1.0   45.9
# 4    1.0   41.3
# 5    1.0   10.8

# %%
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)

# %%
model.params
# Out:
# const    9.311638
# radio    0.202496
# dtype: float64

# %%
predictions = model.predict(X) 
predictions
# Out:
# 1      16.965979
# 2      17.269722
# 3      18.606195
# 4      17.674714
# 5      11.498593
# 6      19.213682
# 7      15.953500
# 8      13.280555
# 9       9.736879
# 10      9.838127
# 11     10.486114
# 12     14.171537
# 13     16.419240
# 14     10.850606
# 15     15.973749
# 16     18.970687
# 17     16.722984
# 18     17.330471
# 19     13.462802
# 20     14.151287
# 21     14.920771
# 22     10.344367
# 23     12.531321
# 24     12.733817
# 25     11.863085
# 26     10.020373
# 27     15.244765
# 28     12.693318
# 29     14.799274
# 30     12.551571
#          ...
# 171    11.660589
# 172    13.543800
# 173    13.381803
# 174    10.749358
# 175    10.000124
# 176    19.213682
# 177    15.427011
# 178    10.891105
# 179     9.777378
# 180    11.336596
# 181     9.838127
# 182    10.405115
# 183    10.465864
# 184    18.018957
# 185    13.624798
# 186    18.444198
# 187     9.736879
# 188    15.123267
# 189    12.126329
# 190    11.761837
# 191    17.634215
# ...

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     10.89
# Date:                Fri, 27 Oct 2017   Prob (F-statistic):            0.00115
# Time:                        10:37:42   Log-Likelihood:                -608.34
# No. Observations:                 200   AIC:                             1221.
# Df Residuals:                     198   BIC:                             1227.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.3514      0.621     19.876      0.000      11.126      13.577
# ...

# %%
ax = df.plot(x='radio', y='sales', kind='scatter') # scatter-plot data

# %%
abline_plot(model_results=model, ax=ax) # plot regression line

# %%
X["const"] = X["const"].apply(lambda x: x*0)
X
# Out:
#      const  radio
# 1      0.0   37.8
# 2      0.0   39.3
# 3      0.0   45.9
# 4      0.0   41.3
# 5      0.0   10.8
# 6      0.0   48.9
# 7      0.0   32.8
# 8      0.0   19.6
# 9      0.0    2.1
# 10     0.0    2.6
# 11     0.0    5.8
# 12     0.0   24.0
# 13     0.0   35.1
# 14     0.0    7.6
# 15     0.0   32.9
# 16     0.0   47.7
# 17     0.0   36.6
# 18     0.0   39.6
# 19     0.0   20.5
# 20     0.0   23.9
# 21     0.0   27.7
# 22     0.0    5.1
# 23     0.0   15.9
# 24     0.0   16.9
# 25     0.0   12.6
# 26     0.0    3.5
# 27     0.0   29.3
# 28     0.0   16.7
# 29     0.0   27.1
# 30     0.0   16.0
# ..     ...    ...
# 171    0.0   11.6
# 172    0.0   20.9
# 173    0.0   20.1
# 174    0.0    7.1
# 175    0.0    3.4
# 176    0.0   48.9
# 177    0.0   30.2
# 178    0.0    7.8
# 179    0.0    2.3
# 180    0.0   10.0
# 181    0.0    2.6
# 182    0.0    5.4
# 183    0.0    5.7
# 184    0.0   43.0
# 185    0.0   21.3
# 186    0.0   45.1
# 187    0.0    2.1
# 188    0.0   28.7
# ...

# %%
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
model.params
# Out:
# const    0.000000
# radio    0.487328
# dtype: float64

# %%
predictions = model.predict(X) 
predictions
# Out:
# 1      18.420991
# 2      19.151983
# 3      22.368346
# 4      20.126638
# 5       5.263140
# 6      23.830330
# 7      15.984352
# 8       9.551625
# 9       1.023388
# 10      1.267052
# 11      2.826501
# 12     11.695867
# 13     17.105206
# 14      3.703691
# 15     16.033085
# 16     23.245536
# 17     17.836198
# 18     19.298181
# 19      9.990220
# 20     11.647135
# 21     13.498980
# 22      2.485372
# 23      7.748512
# 24      8.235840
# 25      6.140330
# 26      1.705647
# 27     14.278705
# 28      8.138374
# 29     13.206584
# 30      7.797245
#          ...
# 171     5.653003
# 172    10.185151
# 173     9.795289
# 174     3.460027
# 175     1.656915
# 176    23.830330
# 177    14.717300
# 178     3.801157
# 179     1.120854
# 180     4.873278
# 181     1.267052
# 182     2.631570
# 183     2.777769
# 184    20.955096
# 185    10.380082
# 186    21.978484
# 187     1.023388
# 188    13.986308
# 189     6.773857
# 190     5.896666
# 191    20.029173
# ...

# %%
model.summary()
# Out:
# /Users/francobonifetto/anaconda/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1471: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/francobonifetto/anaconda/lib/python3.6/site-packages/statsmodels/base/model.py:1036: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /Users/francobonifetto/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/francobonifetto/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/francobonifetto/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# ...

# %%
ax = df.plot(x='radio', y='sales', kind='scatter') # scatter-plot data

# %%
abline_plot(model_results=model, ax=ax) # plot regression line

# %%
N = df["newspaper"]
y = df["sales"]

# %%
N = sm.add_constant(N) 
N.head()
# Out:
#    const  newspaper
# 1    1.0       69.2
# 2    1.0       45.1
# 3    1.0       69.3
# 4    1.0       58.5
# 5    1.0       58.4

# %%
model = sm.OLS(y, N).fit() ## sm.OLS(output, input)

# %%
model.params
# Out:
# const        12.351407
# newspaper     0.054693
# dtype: float64

# %%
predictions = model.predict(N) 
predictions
# Out:
# 1      16.136169
# 2      14.818066
# 3      16.141639
# 4      15.550953
# 5      15.545484
# 6      16.453389
# 7      13.636695
# 8      12.985847
# 9      12.406100
# 10     13.510901
# 11     13.674980
# 12     12.570179
# 13     15.955682
# 14     12.745197
# 15     14.867290
# 16     15.244672
# 17     18.586420
# 18     15.403282
# 19     13.352291
# 20     13.396045
# 21     15.272019
# 22     13.636695
# 23     15.064185
# 24     13.784366
# 25     13.352291
# 26     13.417922
# 27     13.040540
# 28     13.603879
# 29     13.603879
# 30     14.582885
#          ...
# 171    13.357760
# 172    14.943860
# 173    13.281190
# 174    13.051479
# 175    13.067887
# 176    14.637579
# 177    13.461677
# 178    14.276604
# 179    13.647634
# 180    13.314006
# 181    12.805360
# 182    13.849998
# 183    13.975792
# 184    16.278372
# 185    13.992200
# 186    13.423392
# 187    13.806243
# 188    13.346821
# 189    12.553772
# 190    13.631226
# 191    12.668627
# ...

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     10.89
# Date:                Fri, 27 Oct 2017   Prob (F-statistic):            0.00115
# Time:                        10:31:32   Log-Likelihood:                -608.34
# No. Observations:                 200   AIC:                             1221.
# Df Residuals:                     198   BIC:                             1227.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.3514      0.621     19.876      0.000      11.126      13.577
# ...

# %%
an = df.plot(x='newspaper', y='sales', kind='scatter') # scatter-plot data

# %%
abline_plot(model_results=model, ax=an) # plot regression line

# %%
N["const"] = N["const"].apply(lambda x: x*0)
N
# Out:
#      const  newspaper
# 1      0.0       69.2
# 2      0.0       45.1
# 3      0.0       69.3
# 4      0.0       58.5
# 5      0.0       58.4
# 6      0.0       75.0
# 7      0.0       23.5
# 8      0.0       11.6
# 9      0.0        1.0
# 10     0.0       21.2
# 11     0.0       24.2
# 12     0.0        4.0
# 13     0.0       65.9
# 14     0.0        7.2
# 15     0.0       46.0
# 16     0.0       52.9
# 17     0.0      114.0
# 18     0.0       55.8
# 19     0.0       18.3
# 20     0.0       19.1
# 21     0.0       53.4
# 22     0.0       23.5
# 23     0.0       49.6
# 24     0.0       26.2
# 25     0.0       18.3
# 26     0.0       19.5
# 27     0.0       12.6
# 28     0.0       22.9
# 29     0.0       22.9
# 30     0.0       40.8
# ..     ...        ...
# 171    0.0       18.4
# 172    0.0       47.4
# 173    0.0       17.0
# 174    0.0       12.8
# 175    0.0       13.1
# 176    0.0       41.8
# 177    0.0       20.3
# 178    0.0       35.2
# 179    0.0       23.7
# ...

# %%
model = sm.OLS(y, N).fit() ## sm.OLS(output, input)
model.params
# Out:
# const        0.000000
# newspaper    0.323202
# dtype: float64

# %%
model.summary()
# Out:
# /Users/francobonifetto/anaconda/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1471: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/francobonifetto/anaconda/lib/python3.6/site-packages/statsmodels/base/model.py:1036: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /Users/francobonifetto/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/francobonifetto/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/francobonifetto/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# ...

# %%
an = df.plot(x='newspaper', y='sales', kind='scatter') # scatter-plot data

# %%
abline_plot(model_results=model, ax=an) # plot regression line
